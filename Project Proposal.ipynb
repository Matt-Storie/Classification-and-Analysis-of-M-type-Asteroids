# %% [markdown]
# # MATH 4100/COMP 5360 Introduction to Data Science
# # Final Project Proposal
# ## Basic Information
# Project title:Analysis of M-Type Asteroids: Charecterisitcs, distribution, and population charecteristics
# Matthew Storie: u1136903
# Ian Wixom: u1201040

# %% [markdown]
# ## Background and Motivation:
# As our species becomes more proficient in spacefaring and operations, our demand for critical metals such as nickel, iron, gold, palladium, and many others will also increase. M-type (or Metallic) asteroids occur in our system and can be a potential source of material for our civilizations. However, to reach these asteroids will be difficult and potentially very costly. Furthermore, our group does not know what the distribution of M-type asteroids looks like in common asteroid clusters (see right) such as the Asteroid Belt, Jupiter’s Trojans or in the Kuiper Belt. Therefore, by using a comprehensive database from NASA, we can search for potential regions of interest and suggest space mining operations there. Ian is currently a contractor for Ames Research Center who does work on orbital mechanics and software development for the HelioSwarm project, with some experience in prior class research in Lagrangian Points for Intro to Numerical Analysis. Matthew has experience in the University of Utah’s Applied Cognition Laboratory, and working with statistical analysis of complex datasets.
# ![300px-InnerSolarSystem-en.png](attachment:300px-InnerSolarSystem-en.png)

# %% [markdown]
# ## Objectives:
# This project aims to identify what regions of our solar system contain high concentrations of M-type asteroids, and the characteristics of such regions. There are multiple regions of our solar system which have a higher density of asteroids, -asteroid clusters- and the composition of asteroids can vary greatly. Identifying a handful of specific bodies would be helpful for preliminary ventures to test the concept of extracting minerals from asteroids, but a large-scale industry centered around mineral extraction from these bodies would need to know what asteroid clusters are the most rich in M-type asteroids specifically. First, we aim to determine which asteroid cluster contains the greatest density of M-type asteroids in our solar system. Then, we will analyze the distribution of asteroid types in this cluster, density of asteroids overall, distribution of size, and average distance from the orbital path of the Earth. These characteristics should provide a goal to reach toward in future space expeditions, as serious thought on how to begin mineral extraction on asteroids cannot begin until the objective itself is well-defined.
#
# ## Data Description and Acquisition:
# The most useful source for data collection will be Jet Propulsion Laboratory’s Small-Body Database Query. We will set up the CSV with the appropriate options, likely with multiple scenarios (one focusing on Jupiter’s Trojans, another the Kuiper Belt, etc). The information can be accessed with the following link.
#
# ## Ethical considerations:
# This project itself does not have any ethical considerations to speak of, as we will be utilizing publicly available data, and the results are unlikely to even be used in the immediate future. Asteroid mining in general does have a few ethical considerations to note. First, if human operators are needed on the sites, there are serious long-term risks to human health from prolonged time in space that are still not fully understood. Additionally, large-scale space enterprises have a significant environmental impact, and contribute to the ever-growing problem of orbital space junk. This project does not specifically contribute to these issues, but they should be noted when discussing the topic.
#
# ## Data Cleaning and Processing:
# Since many asteroids have not been classified, we will have to do some data cleaning. We are currently researching the particular methodology of classification of asteroids, as this is a critical underlying concept that will guide our methodology. For example, some asteroids are listed in the database with no assignment of size or makeup. Should we include its existence to show regional density? Or should we focus more explicitly on asteroids we have found? In regards to the quantities to derive from our data, we will be considering the spectrology, size, location, and other general conditions available in the JPL query. We will implement a python function for data processing, and save the resulting CSV as the ”working dataset.”
#
# ## Exploratory analysis:
# Our preliminary analysis would largely be composed of determining what asteroid cluster  would be most viable for further analysis of the asteroids within. We expect to do so by setting threshold values of variables which reflect composition to first only examine M-type asteroids, and then determining which region of the solar system has the greatest density of such asteroids. If multiple regions have similar densities, we can use further criteria such as the presence of asteroids which fail to meet the criteria nearby, and distance from the earth’s orbital path. Once the region of interest has been determined, we can then continue the main analysis to answer the research questions mentioned in the objectives section, and determine if there are any changes to the research objectives that should be made from any insights gained at this stage.
#
# ## Analysis Methodology:
# After we clean and load our data, we will be splitting up the analysis in accordance to types of asteroid clusters: Amor Asteroids, Atira Asteroids, Inner, Main-Belt, and Outer Asteroid Belts, Jupiter Trojans and Kuiper Belt. We will utilize both SMASSI and Theron classification types to categorize the concentration of M-Type Asteroids, and the total confirmed amount when considering the size of the asteroid and location relative to the earth among other metrics of interest. It will be critical to consider the spatial distribution of the metallic asteroids in the clusters. Specific planned visualizations include a comparison of M-type asteroids between the clusters, a histogram of size distribution within the cluster of interest, and scatter plots of variables of interest that will be determined once the data of the cluster of interest is characterized. If there are significant variations in one or more of the spectrography variables that are helping us to identify M-type asteroids, we can create heat map or scatter plot visualizations comparing these variables to communicate this variance.
#
# ## Project Schedule:
# To ensure the equitable distribution of work, and ensuring continued communication, we have already determined what times during the week each of us are available to meet, exchanged contact information, discussed preferred communication, and discussed how much each of us prefer to work together or alone. Furthermore, we have discussed individual strengths and experiences coding. During the early stages of the project (before the check-in assignment during the preliminary analysis) we determined that meeting on a weekly basis to exchange work, and discuss clear objectives for the next week would be ideal. During the main analysis, we determined we would meet on an as-needed basis, and communicated largely through email or Discord, as at this point we will just need to update one another on the progress and are unlikely to need conversations about the work to be done during the next week.
# A rough outline of the project is as follows:
#
# -March 19-25 Data Acquisition and compilation. Create a shared github repository for file sharing
#
# -March 26-April 1 Data cleaning, exploratory statistics, determine thresholds for asteroids of interest
#
# -April 2-8 Drafting of milestone document, determine region of interest
#
# -April 9-15 Main analysis on region of interest. Distribution of asteroid size, and obtain metrics of interest.
#
# -April 16-21 Data visualization of the results, presentation recording, and finalized streamlining of the notebook
