# %% [markdown]
# **Rubric**
#
# -Names and UID's of members
#
# 2pts-background and motivation X
#
# 2pts-project objectives: provide the primary questions you are trying to answer in the projext X
#
# 2pts-descriptions of data, sources, etc X
#
# 3pts- Data processing: showcase the data processing step by step X
#
# 5pts- Exploratory Analysis: describe and showcase the exploratory analysis step by step X
#
# 4pts- analysis methodology: discuss the chosen methodology X
# (optional, up to 3 pts)- Data visualization: decrive and showcase the visualization methods
#
# 6pts- Results: a summary of the results
#
# 1pt- Evaluation: What were the metrics used to evaluate how successful your project was?
#
# 3pts- Ethical considerations X
#
# 1pt-Project summary answer the specific questions 1-2 sentences each X
#
#     What is an overview of your project?
#
#     What are your project objectives?
#
#     What are your technical contributions
#
#     what are the main results
#
#     what are the future directions?
#
# 3pts- project video

# %% [markdown]
# ---
# Stuff that we can include
#
# Graph of the metallic vs nonmetallic asteroids, include better labels, and possibly include vertical lines for significant distances like earth, jupiter, mars, etc
#
# Don't omit the analyses that failed, should include in order to accurately decribe the process. This will feed greatly into the results section, since that is a significant source of points
#
# ---
# Stuff that is pretty much aready done:
# - Background and motivation
# - Objectives
# - Data description
# - ethical considerations
# ---
# Stuff that still needs to be done:
# - Data Processing
# - Exploratory analysis
# - Analysis methodology
# - Data visualization module
# - Results
# - Evaluation
# - Summary
# - Video
# ---
# Specific stuff
#
# 1. Get the regex function that derived volume into a presentable format even though we are not really using it meaningfully. Write up some stuff about it when you do it (good efficiency) to transfer to the results section
#
# 2. Get the mirrors of the historgrams and scatter plots in an array next to one another in the final presentation
#
# 3. Add titles and axes labels to plots, improve ticks if needed
# 4. (optional) explain why on number of bins of histograms
# 5. Figure out how to create a more visually appealing display of the counts of the different classifications
# 6. In the methodology section, be sure to include why we are including M and S type asteroids, and not the transition types
# 7. In the data description, be sure to accurately discuss what the variables actually are. For example, why is spectography useful, and mention that diameter is not the observed diameter, but the equal-sphere diameter (what is the diff and why it matters)
# 8. make the model training and actual predictions look prettier
# 9. find a visually pleasing way to present the value counts for the different variables
# 10. Write about the process of adjusting the
# 11. Will need Ian to write about the PCA methodology and results since tbh I dont think I understand it well enough to make an accurate prediction
# 12. **important:** in the results/discussion need to address the differences between the classified asteroids and Machine learning classified asteroids (as groups). The sizes are skewed, as the majority of the large asteroids are in the classified set, which has implications on the results
# 13. (optional) see if there is a way to just present like part of the plot for the already classified asteroids to be zoomed in a bit to match the axes scalings of the ML-Classified asteroids
# 14. Use the sampling function to reduce the number of points that are graphed on the scatter plots since they are difficult to read. Increase size of plots might help?
#     If you do reduce the dots, make seperate plots with the dots reduced? Could fill out a bit of the methodology, since it shows we are able to use feedback from preliminary results to better the analysis
# ---
# Stuff to maybe include
# - Correlation matrix: useful? just pretty? Eh?
# - Testing
